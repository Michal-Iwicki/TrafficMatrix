# %%
import pandas as pd
from codes.plots import plot_vehicle_duration_hist, plot_stop_histogram_percentage
df = pd.read_csv("data/zielona_gora_analizy_testowe_10_05_2023.csv", sep=";")

# %% [markdown]
# Data already sorted and without missing values

# %%
df['timestamp'].is_monotonic_increasing
# Out:
# True

# %%
df.isna().sum()
# Out:
# vehicle_id    0
# timestamp     0
# time          0
# speed         0
# course        0
# lat           0
# lon           0
# dtype: int64

# %% [markdown]
# Typical data from a single vehicle

# %%
df[df["vehicle_id"] == "18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c4457e1ce49b21a21b3ed"]
# Out:
#                                             vehicle_id   timestamp  \
# 139  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692784
# 140  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692794
# 141  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692804
# 142  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692829
# 144  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692839
# 145  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692849
# 146  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692873
# 147  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692883
# 148  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692893
# 149  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692903
# 150  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692913
# 154  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692948
# 157  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692958
# 159  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692968
# 161  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692978
# 164  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692988
# 167  18542b399a8fed3103f7ecfc8c16ea9576b2aa40393c44...  1683692998
#
#                  time  speed  course       lat       lon
# 139  10.05.2023 06:26     25     330  51.93318  15.49877
# 140  10.05.2023 06:26     39     326  51.93389  15.49792
# 141  10.05.2023 06:26     36     340  51.93472  15.49717
# 142  10.05.2023 06:27     10       4  51.93529  15.49689
# 144  10.05.2023 06:27     32     288  51.93577  15.49648
# 145  10.05.2023 06:27     14     308  51.93608  15.49537
# 146  10.05.2023 06:27      7     318  51.93614  15.49526
# 147  10.05.2023 06:28     39     340  51.93673  15.49463
# 148  10.05.2023 06:28     46     350  51.93781  15.49429
# 149  10.05.2023 06:28     32     354  51.93883  15.49409
# 150  10.05.2023 06:28      3     358  51.93926  15.49399
# 154  10.05.2023 06:29      3       6  51.93928  15.49401
# 157  10.05.2023 06:29     28      14  51.93976  15.49412
# 159  10.05.2023 06:29     39     346  51.94055  15.49401
# 161  10.05.2023 06:29     43     354  51.94164  15.49373
# 164  10.05.2023 06:29     39     328  51.94270  15.49322
# 167  10.05.2023 06:29     18     322  51.94323  15.49254

# %%
_= plot_vehicle_duration_hist(df)

# %% [markdown]
# Most of the users, use application less than 10 minutes. We have to decide the threshold after which we consider proper route.

# %%
_ = plot_stop_histogram_percentage(df,include_gaps=True, min_stop_min=0, gap_threshold_sec=60, max_limit_min=60)
_ = plot_stop_histogram_percentage(df,include_gaps=False, min_stop_min=0, gap_threshold_sec=60, max_limit_min=60)
# Out:
# Total stops analyzed: 4099
# Stops after filtering (<0 min removed): 4099
# Median stop duration: 0.37 minutes
# Total stops analyzed: 3688
# Stops after filtering (<0 min removed): 3688
# Median stop duration: 0.17 minutes

# %% [markdown]
# Majority of stops are fake and caused by traffic lights. Also we have to decide thresholds values and whether we treat gaps in messurment as stops or under which conditions

# %%
_ = plot_stop_histogram_percentage(df,include_gaps=True, min_stop_min=2, gap_threshold_sec=60, max_limit_min=60)
_ = plot_stop_histogram_percentage(df,include_gaps=False, min_stop_min=2, gap_threshold_sec=60, max_limit_min=60)
# Out:
# Total stops analyzed: 4099
# Stops after filtering (<2 min removed): 783
# Median stop duration: 9.45 minutes
# Total stops analyzed: 3688
# Stops after filtering (<2 min removed): 195
# Median stop duration: 7.15 minutes
